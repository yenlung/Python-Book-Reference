# %% [markdown]
# 以下是參考解答，事實上所有解答都可以進一步簡化，或是有其他更好的做法，你也來試試看吧！

# %% [markdown]
# 1. 在你的電腦上安裝好Anaconda，然後建一個以後會放「所有」Python程式的工作資料夾，再來用cd進到那個資料夾，執行Jupyter Notebook。（你也可以直接使用Google的Colab，詳情請看接下來的「小旅行」。）

# %%
# 這題自己試試看
