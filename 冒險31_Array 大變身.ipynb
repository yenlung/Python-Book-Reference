# %% [markdown]
# 以下是參考解答，事實上所有解答都可以進一步簡化，或是有其他更好的做法，你也來試試看吧！

# %% [markdown]
# 目前我們看到的如 [1, 2, 3] 叫 1D array，而 [[1,2], [3,4]] 叫 2D array。事實上也可以有 3D array ！比如說我們設arr = np.array(30)，然後你可以試著把這個array 改成 (5, 2, 3) 的形式，看看內容是否懂這是什麼意思？再來我們再把 arr 改成(5, 6) 的形式，這又和之前(5, 2, 3) 形式有什麼關係呢？

# %%
# 這題是讓大家自由嘗試不同維度的array的關係，請自己試試看
