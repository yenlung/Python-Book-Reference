# %% [markdown]
# ## 以下是參考解答，事實上所有解答都可以進一步簡化，或是有其他更好的做法，你也來試試看吧！

# %% [markdown]
# ### 1. 我們再一次做「幾A 幾B 猜數字」遊戲的準備：用choice 選出0 到9 四個不重複的數字，合成一個字串，比如說 '0394'。你是不是發現，我們知道越多之後，可以更快、更簡單寫出我們要的程式？

# %%
import numpy as np
num = np.random.choice([f'{i}' for i in range(10)], 4, replace=False)
num = ''.join(list(num))
