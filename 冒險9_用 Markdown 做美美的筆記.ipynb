# %% [markdown]
# 以下是參考解答，事實上所有解答都可以進一步簡化，或是有其他更好的做法，你也來試試看吧！

# %% [markdown]
# 1. 找一個你有興趣的主題，用Markdown 做筆記好好介紹一下。這個主題是有計算、或是需要寫程式的，可以是個數學問題（比如費波那契數列），可以是一個實務上的數據分析，甚至可以是個小遊戲。你不用現在就會寫這個程式（事實上最好是你現在還寫不出來的），但要記得這件事，日後慢慢想辦法寫出這個程式來。

# %%
# 這題自己試試看
