# %% [markdown]
# 以下是參考解答，事實上所有解答都可以進一步簡化，或是有其他更好的做法，你也來試試看吧！

# %% [markdown]
# 1. 找一個你喜歡的顏文字，並且亂數決定連續顯示幾次。所以每次會得到不同長度、連續顯示的顏文字。

# %%
import numpy as np
n = np.random.randint(1,30)
face = 'ε٩(๑> ₃ <)۶з'
print(face*n)
# Out:
# ε٩(๑> ₃ <)۶з
