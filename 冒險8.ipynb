# %% [markdown]
# ## 以下是參考解答，事實上所有解答都可以進一步簡化，或是有其他更好的做法，你也來試試看吧！

# %% [markdown]
# ### 1. 找出五樣你想購買的東西，設計一個字典變數去記錄這五樣東西的價格。

# %%
buy_dict = {'6塊麥克雞塊':60, '麥香魚':49, '大麥克':72, '麥香雞':44, '麥脆雞翅':90}

# %% [markdown]
# ### 2. 承上題，你又找到一個新的東西，再把它加入你的「欲購買物品資料庫」。

# %%
 buy_dict['勁辣雞腿堡'] = 72
 buy_dict
# Out:
# {'6塊麥克雞塊': 60, '勁辣雞腿堡': 72, '大麥克': 72, '麥脆雞翅': 90, '麥香雞': 44, '麥香魚': 49}
