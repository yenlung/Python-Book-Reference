# %% [markdown]
# 以下是參考解答，事實上所有解答都可以進一步簡化，或是有其他更好的做法，你也來試試看吧！

# %% [markdown]
# 1. 現在我們知道怎麼用pandas 來看資料了，但是只看表格的前5 行可能沒辦法代表所有數據，現在我們想看到DataFrame 的前10 行、最後10 行，還有隨便10 筆數據，請你想想看怎麼做？如果想不到也可以請教最好用的Google 大神。

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('https://bitly.com/gradescsv')
df.head(10) # 前10筆
df.tail(10) # 後10筆
df.sample(10) # 隨便10筆

# %% [markdown]
# 2. 貓貓大學中文系希望錄取文科成績好的學生，請你用前面提供的學測成績，找出國文、英文及社會科平均級分超過13 級分的同學，並把他print 出來。

# %%
print(df.loc[df.loc[:,['國文','英文','社會']].mean(axis=1) > 13,'姓名'].values)
# Out:
# ['黃淑婷' '李正偉' '林秀娟' '曲秀芬' '趙恭群' '林士茜' '柳菁蘭' '陳怡婷' '陳怡潔' '曾昇喬' '施雅鈴']
